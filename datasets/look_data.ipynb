# %%
# %matplotlib inline
from collections import defaultdict
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('TRAIN.csv')
test = pd.read_csv('TEST2.csv')
user = pd.read_csv('USER_PROFILE.csv')
shop = pd.read_csv('SHOP_PROFILE.csv')
trace = pd.read_csv('USER_TRACE.csv')

# %%
print(train.columns)
print(user.columns)
print(trace.columns)
# Out:
# Index(['USERID', 'SHOPID', 'ARRIVAL_TIME'], dtype='object')
# Index(['USERID', 'INCOME', 'ENTERTAINMENT', 'BABY', 'GENDER', 'SHOPPING'], dtype='object')
# Index(['USERID', 'BEGIN_TIME', 'STARTLONGTITUDE', 'STARTLATITUDE', 'DURATION'], dtype='object')

# %%
x = trace.STARTLONGTITUDE
y = trace.STARTLATITUDE
plt.scatter(x, y, s=2, c='b', alpha=0.4, edgecolors='none')
